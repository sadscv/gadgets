# %%
import csv

import matplotlib.pyplot as plt
import pandas
import seaborn

# airports = pandas.read_csv("airports.csv", header=None, dtype=str)

output = []

idx_line = 0
with open ('test_data.csv') as f:
    for line in f:
        idx_line += 1
        line_splits = line.strip().split(' ')
        print(line_splits)
        line_formated = [line_splits[0], 0, 0]
        for s in line_splits:
            if str(s).strip() == 'm':
                line_formated[1] += 1
            elif str(s).strip() == 'f':
                line_formated[2] += 1
        output.append(line_formated)
        
with open('data_output.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(output)
    
output = []
with open ('test_data.csv') as f:
    for line in f:
        line_splits = line.strip().split(' ')
        age, sex = line_splits[0], line_splits[1:]
        if len(sex)>=0:
            for i in sex:
                if i == 'm':
                    output.append([age, 1])
                elif i == 'f':
                    output.append([age, 0])
with open('data_output_bin.csv', 'w') as f:
    writer = csv.writer(f)
    writer.writerows(output)
# Out:
# ['82', 'm']
# ['83']
# ['84', 'm']
# ['85']
# ['86']
# ['87', 'm', 'f']
# ['88', 'm', 'm']
# ['89', 'm', 'm', 'm', 'f', 'm', 'm']
# ['90', 'm', 'm', 'm', 'f', 'm', 'm', 'f', 'm', 'm', 'm', 'm', 'f', 'f', 'f']
# ['91', 'f', 'm', 'f', 'm', 'm', 'f', 'm', 'f', 'f', 'm']
# ['92', 'f', 'm', 'f', 'm', 'm', 'f', 'f']
# ['93', 'm', 'm', 'f', 'f', 'm', 'm']
# ['94', 'f', 'f', 'f', 'm', 'f']
# ['95', 'm', 'm', 'm']
# ['96', 'm']
# ['0', 'm']

# %%
df = pandas.read_csv('data_output.csv',  header=None, dtype=int)
df.head(15)
df.set_index(0)
df.head()
df.T
# df.rename(index=str, columns={0:'a',1:'b',2:'C'})
df.columns = ['age','m','f']
df2 = df.drop(15)


dfb = pandas.read_csv('data_output_bin.csv',  header=None, dtype=int)

dfb.columns = ['age', 'sex']
dfb.tail(15)
dfb
dfb_bak = dfb.copy()
dfb_bak=dfb[:55]
dfb_bak.plot()

# %%
import seaborn as sns
import matplotlib


# %matplotlib inline
sns.set(color_codes=True)
sns.set(style="white", palette="muted")
sns.set_context('talk')
plt.rcParams["xtick.labelsize"] = 10


ax1=sns.distplot(dfb_bak['age'][dfb_bak['sex']==1], color='b')
ax1=sns.distplot(dfb_bak['age'][dfb_bak['sex']==0], color='r')


# ax2=sns.distplot(dfb.age, kde=False, rug=True)
# ax2=sns.distplot(df2['age'][df2['m']],color='b')
# Out:
# C:\Program Files (x86)\Miniconda2\envs\py3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j
